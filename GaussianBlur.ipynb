# %%
# !pip install pymp-pypi
# Out:
# Requirement already satisfied: pymp-pypi in /usr/local/lib/python3.7/dist-packages (0.5.0)

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e1ead34c-eee3-4b51-9b70-a430e32b4b62" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1ead34c-eee3-4b51-9b70-a430e32b4b62">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving coin.png to coin.png

# %%
import numpy as np
from numpy import array
from scipy import misc
from PIL import Image
import imageio
import pymp
import datetime

a = datetime.datetime.now()
pymp.config.nested = True
face = imageio.imread('coin,png')
print (face.shape)
convx = array([[1/16, 2/16, 1/16],
	  [2/16, 4/16, 2/16],
	  [1/16, 2/16, 1/16]])
l=face.shape[0]
b=face.shape[1]
padded = np.zeros((l+2,b+2))
for i in range(0,l):
	for j in range(0,b):
		padded[i+1][j+1]=face[i][j]


res = np.zeros((l,b), dtype='uint8')
i=None
j=None

for i in range(1,l+1):
	for j in range(1,b+1):
		res[i-1][j-1] = (convx[0][0]*padded[i-1][j-1] + convx[0][1]*padded[i-1][j]+convx[0][2]*padded[i-1][j+1]+ 
				convx[1][0]*padded[i][j-1]+convx[1][1]*padded[i][j] + convx[1][2]*padded[i][j+1]+ 
				convx[2][0]*padded[i+1][j-1]+ convx[2][1]*padded[i+1][j] +convx[2][2]*padded[i+1][j+1])
				
	
img = Image.fromarray(res)
img.save('my.png')
img.show()
b = datetime.datetime.now()
print(b-a)
# Out:
# (900, 1200, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-45a69b0c8f4e> in <module>()
#      19 for i in range(0,l):
#      20         for j in range(0,b):
# ---> 21                 padded[i+1][j+1]=face[i][j]
#      22
#      23
#
# ValueError: setting an array element with a sequence.

# %%
import numpy as np
from numpy import array
from scipy import misc
from PIL import Image
import imageio
import pymp
import datetime

a = datetime.datetime.now()
pymp.config.nested = True
face = imageio.imread('coin.jpg')
print (face.shape)
convx = array([[1/16, 2/16, 1/16],
	  [2/16, 4/16, 2/16],
	  [1/16, 2/16, 1/16]])
l=face.shape[0]
b=face.shape[1]
#padded = np.zeros((l+2,b+2))
padded = pymp.shared.array((l+2,b+2), dtype='uint8')
i=None
j=None
with pymp.Parallel(2) as p1:
	with pymp.Parallel(2) as p2: 
		for i in p1.range(0,l):
			for j in p2.range(0,b):
				padded[i+1][j+1]=face[i][j]


res = pymp.shared.array((l,b), dtype='uint8')
i=None
j=None
with pymp.Parallel(2) as p1:
	with pymp.Parallel(2) as p2: 
		for i in p1.range(1,l+1):
			for j in p2.range(1,b+1):
				res[i-1][j-1] = (convx[0][0]*padded[i-1][j-1] + convx[0][1]*padded[i-1][j]+convx[0][2]*padded[i-1][j+1]+ 
						convx[1][0]*padded[i][j-1]+convx[1][1]*padded[i][j] + convx[1][2]*padded[i][j+1]+ 
						convx[2][0]*padded[i+1][j-1]+ convx[2][1]*padded[i+1][j] +convx[2][2]*padded[i+1][j+1])
				
		
img = Image.fromarray(res)
img.save('my.png')
img.show()
b = datetime.datetime.now()
print(b-a)
# Out:
# (900, 1200, 3)
# An exception occured in thread 0: (<class 'ValueError'>, setting an array element with a sequence.).
# An exception occured in thread 0: (<class 'ValueError'>, setting an array element with a sequence.).
# An exception occured in thread 1: (<class 'ValueError'>, setting an array element with a sequence.).
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-9384b6795318> in <module>()
#      25                         for j in p2.range(0,b):
# ---> 26                                 padded[i+1][j+1]=face[i][j]
#      27
#
# ValueError: setting an array element with a sequence.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-9384b6795318> in <module>()
#      25                         for j in p2.range(0,b):
# ---> 26                                 padded[i+1][j+1]=face[i][j]
#      27
#
# /usr/local/lib/python3.7/dist-packages/pymp/__init__.py in __exit__(self, exc_t, exc_val, exc_tb)
#     147                 )
# --> 148                 raise exc_t(exc_val)
#     149         else:
#
# ValueError: setting an array element with a sequence.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-9384b6795318> in <module>()
#      24                 for i in p1.range(0,l):
#      25                         for j in p2.range(0,b):
# ---> 26                                 padded[i+1][j+1]=face[i][j]
#      27
#      28
#
# /usr/local/lib/python3.7/dist-packages/pymp/__init__.py in __exit__(self, exc_t, exc_val, exc_tb)
#     146                     exc_val,
#     147                 )
# --> 148                 raise exc_t(exc_val)
#     149         else:
#     150             if not self._exception_queue.empty():
#
# ValueError: setting an array element with a sequence.
